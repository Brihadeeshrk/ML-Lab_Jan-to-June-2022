# %%
#To Demo the Importance of the Coefficient in the Multiple Linear Regression Equation 
#Predict the CO2 emission of a car where the weight is 2300kg, and the volume is 1300cm3

import pandas
from sklearn import linear_model

df = pandas.read_csv("sample_data/cars.csv")

X = df[['Weight', 'Volume']]
y = df['CO2']

regr = linear_model.LinearRegression()
regr.fit(X, y)

#predict the CO2 emission of a car where the weight is 2300kg, and the volume is 1300cm3:
predictedCO2 = regr.predict([[2300, 1300]])

print("The CO2 emission of a car with weight 2300kg, and volume 1300cm3 is ", predictedCO2, "gms")

print("Regression Coefficient for Weight is :", regr.coef_[0])
print("Regression Coefficient for Volume is :", regr.coef_[1])
# Out:
# The CO2 emission of a car with weight 2300kg, and volume 1300cm3 is  [107.2087328] gms
# Regression Coefficient for Weight is : 0.00755094727030069
# Regression Coefficient for Volume is : 0.007805257527747127
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"

# %%
#Result Explained
#The result array represents the coefficient values of weight and volume.

#Weight: 0.00755095
#Volume: 0.00780526

#These values tell us that if the weight increase by 1kg, the CO2 emission increases by 0.00755095g.

#And if the engine size (Volume) increases by 1 cm3, the CO2 emission increases by 0.00780526 g.

# %%
#Increase the weight by 1000Kg that is. from 2300kg to 3300kg. Let Volume remain the same
predictedCO2 = regr.predict([[3300, 1300]])

print("A car with 1.3 liter engine, and a weight of 3300 kg, will release approximately ", predictedCO2, "gms of CO2")
# Out:
# A car with 1.3 liter engine, and a weight of 3300 kg, will release approximately  [114.75968007] gms of CO2
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"

# %%
#Which shows that the coefficient of 0.00755095 for Weight is correct:
#Predicted Weight + Increased Weight * Weight Coefficient 
#107.2087328 + (1000 * 0.00755095) = 114.75968


#Source: https://www.w3schools.com/python/python_ml_multiple_regression.asp
